# %%
import csv

# %%
dataset = list(csv.reader(open("AmericanGallery.csv", encoding="utf-8")))

# %%
dataset[0]
# Out:
# ['Title',
#  'Artist',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Department']

# %%
dataset[0].index("Gender")
# Out:
# 5

# %%
"(danial gauhar)".replace(" ","@").replace("(","").replace(")","")
# Out:
# 'danial@gauhar'

# %%
for i in dataset[1:]:
    i[2] = i[2].replace("(","").replace(")","")
    print(i[2])
# Out:
# American
# Spanish
# French
# French
# French
# American
# French
# American
# South African
# Canadian
# French
# American
# Czech
# American
# American
# American
# Belgian
# American
# American
# Spanish
# American
# Russian
# American
# French
# French
# French
# British
# French
# French
# German
# Belgian
#
# American
# American
# American
# Swiss
#
# American
# American
# Polish
# British
# American
# American
# Belgian
# American
# Japanese
# American
# American
# Spanish
# American
# French
# American
# American
# American
# American
# French
# American
# American
# French
# American
# American
# Portuguese
# American
# American
# Austrian
# Swiss
# German
# American
# American
# French
# British
# American
# French
# American
# British
# German
# French
# French
# Australian
# American
# French
# Spanish
# German
# American
# American
# French
# American
# American
# American
# French
# Italian
# American
# American
# American
# American
# American
# French
# American
# ...

# %%
dataset[1]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  '-1947',
#  '-2013',
#  '(Female)',
#  '1986',
#  'Prints & Illustrated Books']

# %%
for i in dataset[1:]:
    i[5] = i[5].replace("(","").replace(")","")
    print(i[5])
# Out:
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Male
# ...

# %%
dataset[1]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  '-1947',
#  '-2013',
#  'Female',
#  '1986',
#  'Prints & Illustrated Books']

# %%
for i in dataset[1:]:
    print(int(i[3].replace("-","")))
# Out:
# 1947
# 1916
# 1870
# 1861
# 1857
# 1919
# 1857
# 1928
# 1964
# 1882
# 1901
# 1935
# 1871
# 1894
# 1955
# 1878
# 1927
# 1936
# 1867
# 1932
# 1886
# 1894
# 1938
# 1926
# 1898
# 1867
# 1947
# 1868
# 1857
# 1938
# 1889
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8344\3597768700.py in <module>
#       1 for i in dataset[1:]:
# ----> 2     print(int(i[3].replace("-","")))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
int("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8344\2022679966.py in <module>
# ----> 1 int("")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
for i in dataset[1:]:
    if i[3] != "":
        i[3] = int(i[3].replace("-",""))

# %%
for i in dataset[1:]:
    if i[4] != "":
        i[4] = int(i[4].replace("-",""))

# %%
dataset[1]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  '-1947',
#  2013,
#  'Female',
#  '1986',
#  'Prints & Illustrated Books']

# %%
bad_char = ["(",")",".","c","C","'"," ","S","s"]

# %%
for i in dataset[1:]: # i = c. 1955-1960
    for j in bad_char:
        i[6] = i[6].replace(j,"")
    print(i[6])
# Out:
# 1986
# 1978
# 1889-1911
# 1927-1940
# 1903
# 1957
# 1924
# 1978-1983
# 2001
# -1941
# 1949-1950
# 1963
# 1908-1911
# -1934
# 1997
# 1931-1933
# 1972
# 1967
# 1923-1924
# 1979
# 1925-1927
# 1929
# 1972
# 1974
# 1957
# 1920-1930
# 1974
# 1915
# 1912
# 1988-1990
# 1925
# 1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 1923-1925
# 1967
# 1932
# 1928
# 1965
# 2003
# 1971-1974
# 1983
# 1930
# 1946
# 1984
# 2006
# 1885
# 1942
# 1913
# 2015
# 1987
# 1947-1949
# 1965
# 1818
# 1961
# 1925
# 1916-1932
# 1962
# 1944
# 1930
# 1991
# 1991-1994
# 2008
# 1975
# 1893
# 1966
# 1968-1969
# 1964-1968
# 1928-1939
# 1969
# 1942
# 1980
# 1955
# 1930
# 1955-1960
# 1922
# 1934
# 1903
# 2008
# 1962
# 1944
# 1914-1918
# -2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# 1986
# ...

# %%
for i in dataset[1:]:
    if "-" in i[6]:
        print(i[6])
# Out:
# 1889-1911
# 1927-1940
# 1978-1983
# -1941
# 1949-1950
# 1908-1911
# -1934
# 1931-1933
# 1923-1924
# 1925-1927
# 1920-1930
# 1988-1990
# 1923-1925
# 1971-1974
# 1947-1949
# 1916-1932
# 1991-1994
# 1968-1969
# 1964-1968
# 1928-1939
# 1955-1960
# 1914-1918
# -2003
# 1908-1911
# -1926
# 1933-1947
# 1968-1977
# 1919-1920
# 1923-1948
# 1912-1926
# 1926-1946
# 1991-1994
# 1936-1937
# 1978-1979
# 1919-1920
# 1965-1966
# 1923-1951
# 1970-1971
# 1959-1965
# 1949-1950
# 1921-1922
# 1947-1955
# 1953-1954
# 1943-1981
# 1931-1956
# 1971-1973
# 1955-1956
# 1899-1900
# 1911-1950
# 1946-1949
# 1908-1911
# 1946-1947
# 1970-1972
# 1925-1927
# 1971-1974
# 1900-1953
# 2008-2010
# 1943-1981
# 1925-1927
# 1989-1990
# 1999-2001
# 1962-1965
# 1930-1931
# 1979-1984
# 1938-1960
# 1923-1948
# 1998-2003
# 1977-1978
# 1997-2000
# 1928-1939
# 1908-1950
# 1926-1938
# 1906-1912
# 1975-1976
# 1900-1943
# ...

# %%
for i in dataset[1:]:
    if "-" in i[6] and len(i[6]) != 9:
        print(i[6])
# Out:
# 1910-30
# 1910-30
# 1880-90
# 1910-30

# %%
string = "1910-30"
string
# Out:
# '1910-30'

# %%
string[:5] + string[:2] + string[5:]
# Out:
# '1910-1930'

# %%
for i in dataset[1:]:
    if "-" in i[6] and len(i[6]) != 9:
        string = i[6]
        i[6] = string[:5] + string[:2] + string[5:]

# %%
for i in dataset[1:]:
    if "-" in i[6] and len(i[6]) != 9:
        print(i[6])

# %%
string = "1966-1968"

lst = string.split("-")
lst
# Out:
# ['1966', '1968']

# %%
round((int(lst[0]) + int(lst[1]))/len(lst))
# Out:
# 1967

# %%
for i in dataset[1:]:
    if "-" in i[6]:
        lst = i[6].split("-")
        avg = round((int(lst[0]) + int(lst[1]))/len(lst))
        i[6] = avg
        print

# %%
dataset[1]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  '-1947',
#  2013,
#  'Female',
#  '1986',
#  'Prints & Illustrated Books']

# %%
for i in dataset[1:]:
    i[6] = int(i[6])

# %%
dataset[1]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  1947,
#  2013,
#  'Female',
#  1986,
#  'Prints & Illustrated Books',
#  3960,
#  3933]

# %%
dataset[0].index ('EndDate')
# Out:
# 4

# %%
for i in dataset[1:]:
    if i[3] != "" and i[4] != "":
        i.append (int(i[4]) - int(i[3]))

# %%
dataset[0].append ("Actual Age")

# %%
dataset[0].index ('Date')
# Out:
# 6

# %%
for i in dataset[1:]:
    if i[3] != "" and i[6] != "":
        i.append (int(i[6]) - int(i[3]))

# %%
dataset[0].append ("Submission Age")

# %%
dataset
# Out:
# [['Title',
#   'Artist',
#   'Nationality',
#   'BeginDate',
#   'EndDate',
#   'Gender',
#   'Date',
#   'Department',
#   'Actual Age',
#   'Submission Age',
#   'Actual Age',
#   'Submission Age'],
#  ['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   'American',
#   1947,
#   2013,
#   'Female',
#   1986,
#   'Prints & Illustrated Books',
#   3960,
#   3933,
#   66,
#   39],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   'Spanish',
#   1916,
#   2007,
#   'Male',
#   1978,
#   'Prints & Illustrated Books',
#   3923,
#   3894,
#   91,
#   62],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   'French',
#   1870,
#   1943,
#   'Male',
#   1900,
#   'Prints & Illustrated Books',
#   3813,
#   3770,
#   73,
#   30],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN',
#   'Aristide Maillol',
#   'French',
#   1861,
#   1944,
#   'Male',
#   1934,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8344\2682102460.py in <module>
# ----> 1 dataset[0].type
#
# AttributeError: 'list' object has no attribute 'type'
